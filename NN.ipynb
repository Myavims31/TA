# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import LSTM
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt
# Out:
# 2023-06-29 22:04:43.202693: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-29 22:04:43.256687: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-29 22:04:43.257496: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 22:04:44.265053: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Pembutan Model/Arsitektur Neural Network
dnn_model=tf.keras.models.Sequential([
    tf.keras.layers.Dense(400),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dense(400),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dense(400),
    tf.keras.layers.Activation('relu'),
    # tf.keras.layers.Dense(50),
    # tf.keras.layers.Activation('relu'),
    # tf.keras.layers.Dense(20),
    # tf.keras.layers.Activation('relu'),
    #tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4, activation="linear")
])

# %%
# costom loss function
def rmse(y_true, y_pred): #Trial
  return K.sqrt(K.mean(K.square(y_pred-y_true)))

def lms(y_true,y_pred): #by simon haykin book's
  return (K.square(y_pred-y_true))/2

# %%
# Model Compiler dengan least mean square untuk loss and Adam untuk optimizer
dnn_model.compile(loss=lms, optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001))

# %%
# Dataset
df = pd.read_csv('J1_Atas Bawah.csv')
df.dropna(inplace=True)

df = df.sample(frac = 1)

X = df[['x', 'y', 'z', 'roll', 'pitch', 'yaw']]
y = df[['theta1', 'theta2', 'theta3', 'theta4']]

train_size = int(0.80 * len(df)) #by Sebastian Raschka book's
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Fungsi Pembatasan Error/Loss
class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        print("Checking loss at end of epoch...")
        if logs['val_loss'] <= 0.00001:             #by TA 2017 ("Tegar Wangi Arlean")
               self.model.stop_training = True
        else:
          print ('not yet...')

# %%
# Training dataset
loss_callback_obj = myCallback()
dnn_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10000, batch_size=200, verbose=1, callbacks=[loss_callback_obj]);
# Out:
# Epoch 1/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.2647Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 1s 43ms/step - loss: 0.2647 - val_loss: 0.2540
# Epoch 2/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.2550Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2550 - val_loss: 0.2452
# Epoch 3/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2681Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2460 - val_loss: 0.2371
# Epoch 4/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.2375Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2375 - val_loss: 0.2296
# Epoch 5/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2316Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2296 - val_loss: 0.2225
# Epoch 6/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2212Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2224 - val_loss: 0.2160
# Epoch 7/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.2156Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2156 - val_loss: 0.2102
# Epoch 8/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2158Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2095 - val_loss: 0.2047
# Epoch 9/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2045Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2037 - val_loss: 0.1997
# Epoch 10/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1986Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1986 - val_loss: 0.1952
# Epoch 11/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1939Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1939 - val_loss: 0.1911
# Epoch 12/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1902Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1895 - val_loss: 0.1872
# Epoch 13/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1855Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1855 - val_loss: 0.1837
# Epoch 14/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1818Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1818 - val_loss: 0.1805
# Epoch 15/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1784Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1784 - val_loss: 0.1775
# Epoch 16/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1753Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1753 - val_loss: 0.1748
# Epoch 17/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1725Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1724 - val_loss: 0.1723
# Epoch 18/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1699Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1699 - val_loss: 0.1700
# Epoch 19/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1720Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1674 - val_loss: 0.1678
# Epoch 20/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1645Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1652 - val_loss: 0.1657
# Epoch 21/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1626Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1629 - val_loss: 0.1637
# Epoch 22/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1615Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1608 - val_loss: 0.1618
# Epoch 23/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1595Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1588 - val_loss: 0.1599
# Epoch 24/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1493Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1568 - val_loss: 0.1581
# Epoch 25/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1550Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1550 - val_loss: 0.1563
# Epoch 26/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1464Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1531 - val_loss: 0.1546
# Epoch 27/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1510Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1513 - val_loss: 0.1529
# Epoch 28/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1559Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1496 - val_loss: 0.1512
# Epoch 29/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1480Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1478 - val_loss: 0.1495
# Epoch 30/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1464Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1460 - val_loss: 0.1479
# Epoch 31/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1444Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1444 - val_loss: 0.1463
# Epoch 32/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1428Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1428 - val_loss: 0.1447
# Epoch 33/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1412Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1411 - val_loss: 0.1431
# Epoch 34/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1395Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1395 - val_loss: 0.1416
# Epoch 35/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1384Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1380 - val_loss: 0.1400
# Epoch 36/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1357Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1364 - val_loss: 0.1385
# Epoch 37/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1348Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1348 - val_loss: 0.1369
# Epoch 38/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1334Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1333 - val_loss: 0.1354
# Epoch 39/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1388Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1317 - val_loss: 0.1339
# Epoch 40/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1302Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1302 - val_loss: 0.1323
# Epoch 41/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1247Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1287 - val_loss: 0.1308
# Epoch 42/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1272Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1272 - val_loss: 0.1293
# Epoch 43/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1257Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1257 - val_loss: 0.1278
# Epoch 44/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1193Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1242 - val_loss: 0.1264
# Epoch 45/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1230Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1229 - val_loss: 0.1251
# Epoch 46/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1214Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1214 - val_loss: 0.1236
# Epoch 47/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1192Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1200 - val_loss: 0.1223
# Epoch 48/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1186Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1186 - val_loss: 0.1209
# Epoch 49/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1204Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1172 - val_loss: 0.1195
# Epoch 50/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1158Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1158 - val_loss: 0.1181
# Epoch 51/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1158Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1145 - val_loss: 0.1168
# Epoch 52/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1131Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1131 - val_loss: 0.1154
# Epoch 53/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1111Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1118 - val_loss: 0.1141
# Epoch 54/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1044Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1105 - val_loss: 0.1128
# Epoch 55/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1165Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1092 - val_loss: 0.1115
# Epoch 56/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1080Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1080 - val_loss: 0.1102
# Epoch 57/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1062Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1067 - val_loss: 0.1089
# Epoch 58/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1054Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1054 - val_loss: 0.1077
# Epoch 59/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1035Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1041 - val_loss: 0.1064
# Epoch 60/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.1028Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1028 - val_loss: 0.1051
# Epoch 61/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1018Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1016 - val_loss: 0.1040
# Epoch 62/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0963Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1004 - val_loss: 0.1028
# Epoch 63/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0992Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0992 - val_loss: 0.1016
# Epoch 64/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0997Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0980 - val_loss: 0.1003
# Epoch 65/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0969Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0969 - val_loss: 0.0992
# Epoch 66/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0958Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0958 - val_loss: 0.0981
# Epoch 67/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0949Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0947 - val_loss: 0.0971
# Epoch 68/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0994Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0936 - val_loss: 0.0960
# Epoch 69/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0926Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0926 - val_loss: 0.0949
# Epoch 70/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0870Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0915 - val_loss: 0.0939
# Epoch 71/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0905Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0905 - val_loss: 0.0929
# Epoch 72/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0895Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0895 - val_loss: 0.0919
# Epoch 73/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0886Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0886 - val_loss: 0.0908
# Epoch 74/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0876Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0876 - val_loss: 0.0898
# Epoch 75/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0867Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0867 - val_loss: 0.0889
# Epoch 76/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0863Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0857 - val_loss: 0.0880
# Epoch 77/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0913Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0848 - val_loss: 0.0871
# Epoch 78/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0838Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0838 - val_loss: 0.0861
# Epoch 79/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0827Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0829 - val_loss: 0.0852
# Epoch 80/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0820Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0820 - val_loss: 0.0842
# Epoch 81/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0811Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0811 - val_loss: 0.0833
# Epoch 82/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0802Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0802 - val_loss: 0.0823
# Epoch 83/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0791Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0793 - val_loss: 0.0814
# Epoch 84/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0731Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0784 - val_loss: 0.0805
# Epoch 85/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.
10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0328Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0328 - val_loss: 0.0343
# Epoch 143/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0322Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0320 - val_loss: 0.0335
# Epoch 144/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0314Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0313 - val_loss: 0.0327
# Epoch 145/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 0.0315Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0305 - val_loss: 0.0319
# Epoch 146/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0298Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0298 - val_loss: 0.0312
# Epoch 147/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0290Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0290 - val_loss: 0.0304
# Epoch 148/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 0.0279Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0283 - val_loss: 0.0296
# Epoch 149/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0275Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0276 - val_loss: 0.0289
# Epoch 150/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0270Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0268 - val_loss: 0.0282
# Epoch 151/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0260Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0261 - val_loss: 0.0274
# Epoch 152/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0252Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0254 - val_loss: 0.0267
# Epoch 153/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0247Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0247 - val_loss: 0.0259
# Epoch 154/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0240Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0240 - val_loss: 0.0252
# Epoch 155/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0233Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0233 - val_loss: 0.0245
# Epoch 156/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0227Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0226 - val_loss: 0.0238
# Epoch 157/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0219Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0219 - val_loss: 0.0231
# Epoch 158/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0211Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0213 - val_loss: 0.0224
# Epoch 159/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0206Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0206 - val_loss: 0.0217
# Epoch 160/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 0.0199Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0200 - val_loss: 0.0211
# Epoch 161/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0193Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0194 - val_loss: 0.0205
# Epoch 162/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0187Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0187 - val_loss: 0.0197
# Epoch 163/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0181Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0181 - val_loss: 0.0191
# Epoch 164/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0175Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0175 - val_loss: 0.0184
# Epoch 165/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0168Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0168 - val_loss: 0.0179
# Epoch 166/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0163Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0163 - val_loss: 0.0173
# Epoch 167/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0158Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0157 - val_loss: 0.0166
# Epoch 168/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 0.0153Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0152 - val_loss: 0.0161
# Epoch 169/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0146Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0146 - val_loss: 0.0156
# Epoch 170/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0142Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0141 - val_loss: 0.0150
# Epoch 171/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0151Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0136 - val_loss: 0.0145
# Epoch 172/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0132Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 173/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0126Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 174/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0122Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0121 - val_loss: 0.0130
# Epoch 175/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0117Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0117 - val_loss: 0.0125
# Epoch 176/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0111Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0112 - val_loss: 0.0120
# Epoch 177/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 0.0110Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0108 - val_loss: 0.0116
# Epoch 178/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0104Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0103 - val_loss: 0.0111
# Epoch 179/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0100Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0099 - val_loss: 0.0107
# Epoch 180/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0096Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0095 - val_loss: 0.0102
# Epoch 181/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0091Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0091 - val_loss: 0.0099
# Epoch 182/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0087Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 183/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0084Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 184/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0080Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0080 - val_loss: 0.0086
# Epoch 185/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0076Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0076 - val_loss: 0.0083
# Epoch 186/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0073Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0079
# Epoch 187/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0069Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 188/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0067Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0066 - val_loss: 0.0072
# Epoch 189/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0063Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0069
# Epoch 190/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0059Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 191/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0058Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 192/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0055Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 193/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0053Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 194/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0050Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 195/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0048Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 196/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0047Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 197/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0044Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 198/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0042Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 199/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0043Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 200/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0038Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 201/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0037Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 202/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 0.0039Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 203/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0033Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 204/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0032Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 205/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0031Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 206/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0029Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 207/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0028Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 208/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0027Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 209/10000
# 7/7 [==============================] - ETA: 0s - loss: 0.0026Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 210/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 0.
-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 22ms/step - loss: 1.2753e-05 - val_loss: 1.2210e-05
# Epoch 2531/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 1.2599e-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 21ms/step - loss: 1.2479e-05 - val_loss: 1.1910e-05
# Epoch 2532/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 1.2181e-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 25ms/step - loss: 1.1968e-05 - val_loss: 1.0420e-05
# Epoch 2533/10000
# 5/7 [====================>.........] - ETA: 0s - loss: 1.0944e-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 22ms/step - loss: 1.1412e-05 - val_loss: 1.0481e-05
# Epoch 2534/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 1.1642e-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1578e-05 - val_loss: 1.0087e-05
# Epoch 2535/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 1.1607e-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1504e-05 - val_loss: 1.0267e-05
# Epoch 2536/10000
# 7/7 [==============================] - ETA: 0s - loss: 1.1532e-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1532e-05 - val_loss: 1.0109e-05
# Epoch 2537/10000
# 1/7 [===>..........................] - ETA: 0s - loss: 1.0787e-05Checking loss at end of epoch...
# not yet...
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1292e-05 - val_loss: 1.1118e-05
# Epoch 2538/10000
# 6/7 [========================>.....] - ETA: 0s - loss: 1.2044e-05Checking loss at end of epoch...
# 7/7 [==============================] - 0s 17ms/step - loss: 1.1986e-05 - val_loss: 9.8607e-06

# %%
tf.keras.models.save_model(dnn_model, "ModelNN.h5")

# %%
# Perbandingan loss dan validation loss
history_df =pd.DataFrame(dnn_model.history.history)
loss_plot = history_df[['loss', 'val_loss']].plot()
loss_plot.set_xlabel('Iterasi')
loss_plot.set_ylabel('Loss')
fig = loss_plot.get_figure()
plt.show()

#fig.savefig('E:/ACA/File ITS/Jurusan/Kuliah Akademik/kuliah semester 8/Tugas Akhir/Dokumentasi/Grafik/Grafik Error PO/e1_h5_n50_n300_n100_n50_n20 (e0.00001).png')

# %%
# Testing
X_target = X_test.iloc[0:].values
Y_target = y_test.iloc[0:].values

Y_prediksi = dnn_model.predict(X_target)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
asd = np.concatenate([X_target, Y_target, Y_prediksi], axis=1)
column_labels = ['x','y','z','roll','pitch','yaw','theta1','theta2','theta3','theta4','theta1_Pred','theta2_pred','theta3_pred','theta4_pred']
df = pd.DataFrame(asd, columns=column_labels)
df

#df.to_csv('test_h3_n400_n400_n400_.csv', index=False)
# Out:
#          x      y      z   roll  pitch    yaw  theta1  theta2  theta3  theta4
# 0    0.143 -0.226  0.118  3.141  2.799  2.093  -1.047   0.454   0.567  -1.363  \
# 1    0.253 -0.139  0.158  3.141  2.712  2.618  -0.523   0.379   0.333  -1.141
# 2    0.149 -0.237  0.144  3.140  2.741  2.095  -1.047   0.404   0.408  -1.213
# 3    0.136  0.215  0.331  0.002  0.734  1.049   1.047   0.119  -0.504  -0.350
# 4    0.143  0.131  0.396  0.000  0.874  0.786   0.785   0.000  -0.873   0.000
# ..     ...    ...    ...    ...    ...    ...     ...     ...     ...     ...
# 303  0.172 -0.092  0.396  3.141  2.269  2.619  -0.523   0.000  -0.873   0.000
# 304  0.296  0.000  0.190  0.000  0.489  0.000   0.000   0.329   0.171  -0.988
# 305  0.190  0.178  0.103  0.000  0.304  0.785   0.785   0.486   0.669  -1.460
# 306  0.251  0.000  0.089  0.000  0.265  0.000   0.000   0.521   0.779  -1.564
# 307  0.205  0.000  0.390  0.000  0.856  0.000   0.000   0.014  -0.829  -0.042
#
#      theta1_Pred  theta2_pred  theta3_pred  theta4_pred
# 0      -1.053467     0.454452     0.568585    -1.364945
# 1      -0.529216     0.380763     0.336953    -1.146118
# 2      -1.052568     0.404924     0.410656    -1.214678
# 3       1.043396     0.118553    -0.499692    -0.354344
# 4       0.785948     0.000671    -0.870221    -0.001970
# ..           ...          ...          ...          ...
# 303    -0.521004     0.000613    -0.866263    -0.003815
# 304    -0.002080     0.327970     0.168355    -0.985543
# 305     0.785210     0.486859     0.672193    -1.464456
# 306    -0.000174     0.519232     0.775121    -1.559816
# 307     0.000254     0.013586    -0.829194    -0.040259
#
# [308 rows x 14 columns]

# %%
# Data Tabel dan Grafik Hasil Testing
dataf = pd.DataFrame({'theta1':Y_target[:,0], 'theta1_pred':Y_prediksi[:,0],
                  'theta2':Y_target[:,1], 'theta2_pred':Y_prediksi[:,1],
                  'theta3':Y_target[:,2], 'theta3_pred':Y_prediksi[:,2],
                  'theta4':Y_target[:,3], 'theta4_pred':Y_prediksi[:,3]}).sort_values(by=['theta1'])

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,5))
axes = ax.flatten()

axes[0].plot([i for i in range(len(dataf))], dataf['theta1'], label='theta1')
axes[0].plot([i for i in range(len(dataf))], dataf['theta1_pred'], label='theta1_pred')
axes[0].set_title('theta1')
axes[0].legend(bbox_to_anchor=(1.1, 1.05))
axes[0].set_xlabel('Jumlah Data')
axes[0].set_ylabel('Nilai Theta')

axes[1].plot([i for i in range(len(dataf))], dataf['theta2'], label='theta2')
axes[1].plot([i for i in range(len(dataf))], dataf['theta2_pred'], label='theta2_pred')
axes[1].set_title('theta2')
axes[1].legend(bbox_to_anchor=(1.1, 1.05))
axes[1].set_xlabel('Jumlah Data')
axes[1].set_ylabel('Nilai Theta')

axes[2].plot([i for i in range(len(dataf))], dataf['theta3'], label='theta3')
axes[2].plot([i for i in range(len(dataf))], dataf['theta3_pred'], label='theta3_pred')
axes[2].set_title('theta3')
axes[2].legend(bbox_to_anchor=(1.1, 1.05))
axes[2].set_xlabel('Jumlah Data')
axes[2].set_ylabel('Nilai Theta')

axes[3].plot([i for i in range(len(dataf))], dataf['theta4'], label='theta4')
axes[3].plot([i for i in range(len(dataf))], dataf['theta4_pred'], label='theta4_pred')
axes[3].set_title('theta4')
axes[3].legend(bbox_to_anchor=(1.1, 1.05))
axes[3].set_xlabel('Jumlah Data')
axes[3].set_ylabel('Nilai Theta')

plt.tight_layout()
dataf

#plt.savefig('E:/ACA/File ITS/Jurusan/Kuliah Akademik/kuliah semester 8/Tugas Akhir/Dokumentasi/Grafik/Grafik Joint PO/J1_h5_n50_n300_n100_n50_n20 (e0.00001).png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 10
#       7 fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,5))
#       8 axes = ax.flatten()
# ---> 10 axes[0].plot([i for i in range(len(dataf))], dataf['theta1'], label='theta1')
#      11 axes[0].plot([i for i in range(len(dataf))], dataf['theta1_pred'], label='theta1_pred')
#      12 axes[0].set_title('theta1')
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:1665, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1434 """
#    1435 Plot y versus x as lines and/or markers.
#    1436
#    (...)
#    1662 (``'green'``) or hex strings (``'#008000'``).
#    1663 """
#    1664 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666 for line in lines:
#    1667     self.add_line(line)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:225, in _process_plot_var_args.__call__(self, *args, **kwargs)
#     223     this += args[0],
#     224     args = args[1:]
# --> 225 yield from self._plot_args(this, kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:387, in _process_plot_var_args._plot_args(self, tup, kwargs)
#     385 if len(tup) == 2:
#     386     x = _check_1d(tup[0])
# --> 387     y = _check_1d(tup[-1])
#     388 else:
#     389     x, y = index_of(tup[-1])
#
# File /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402, in _check_1d(x)
#    1400 else:
#    1401     try:
# -> 1402         ndim = x[:, None].ndim
#    1403         # work around https://github.com/pandas-dev/pandas/issues/27775
#    1404         # which mean the shape is not as expected. That this ever worked
#    1405         # was an unintentional quirk of pandas the above line will raise
#    1406         # an exception in the future.
#    1407         if ndim < 2:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1033, in Series.__getitem__(self, key)
#    1030     key = np.asarray(key, dtype=bool)
#    1031     return self._get_values(key)
# -> 1033 return self._get_with(key)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1048, in Series._get_with(self, key)
#    1043     raise TypeError(
#    1044         "Indexing a Series with DataFrame is not "
#    1045         "supported, use the appropriate DataFrame column"
#    1046     )
#    1047 elif isinstance(key, tuple):
# -> 1048     return self._get_values_tuple(key)
#    1050 elif not is_list_like(key):
#    1051     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1052     return self.loc[key]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1082, in Series._get_values_tuple(self, key)
#    1077 if com.any_none(*key):
#    1078     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1079     #  see tests.series.timeseries.test_mpl_compat_hack
#    1080     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1081     result = np.asarray(self._values[key])
# -> 1082     disallow_ndim_indexing(result)
#    1083     return result
#    1085 if not isinstance(self.index, MultiIndex):
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexers/utils.py:343, in disallow_ndim_indexing(result)
#     335 """
#     336 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     337
#    (...)
#     340 in GH#30588.
#     341 """
#     342 if np.ndim(result) > 1:
# --> 343     raise ValueError(
#     344         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     345         "supported. Convert to a numpy array before indexing instead."
#     346     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
# Mean Square Error
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_target, Y_prediksi)
# Out:
# 1.9721397348107836e-05

# %%
# Root Mean Square Error
rmse(Y_target, Y_prediksi)
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.00444087799293201>

# %%
dataf.to_csv('data.csv', index=False)

# %%
# Data Predict
# Masukan Input disini
loaded_model = tf.keras.models.load_model("ModelNN.h5", custom_objects={"lms": lms })
data = {
    'x': 0.072,
    'y': 0.219,
    'z': 0.365,
    'roll': 0.001,
    'pitch': 1.047,
    'yaw': 1.31
}

# Create a DataFrame with a single row
df = pd.DataFrame(data, index=[0])

Y_prediksi = loaded_model.predict(df)
print(Y_prediksi)
# Out:
# 1/1 [==============================] - 0s 122ms/step
# [[ 1.2725406   0.00907816 -0.90378994 -0.04343066]]

# %%
dnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 400)               2800
#
#  activation_3 (Activation)   (None, 400)               0
#
#  dense_5 (Dense)             (None, 400)               160400
#
#  activation_4 (Activation)   (None, 400)               0
#
#  dense_6 (Dense)             (None, 400)               160400
#
#  activation_5 (Activation)   (None, 400)               0
#
#  dense_7 (Dense)             (None, 4)                 1604
#
# =================================================================
# Total params: 325,204
# Trainable params: 325,204
# Non-trainable params: 0
# _________________________________________________________________
